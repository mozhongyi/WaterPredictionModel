# %%
# -*- coding: utf-8 -*-

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import math, time
from sklearn.metrics import mean_squared_error
import plotly.express as px
import plotly.graph_objects as go
import joblib

import matplotlib.pyplot as plt
plt.rc('font', family='SimHei', size=14)  ##显示中文

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
file_path = './OutputData/水8-12.xlsx'
df = pd.read_excel(file_path)
# df = df.iloc[6572:]
# 将“时间”列转换为 datetime 类型，方便按时间属性筛选
# df["时间"] = pd.to_datetime(df["时间"])
# df = df[(df["时间"].dt.minute == 0) & (df["时间"].dt.second == 0)]
# df.to_excel("./OutputData/水8-12.xlsx",index=False)

# %%
df
# Out:
#                       时间      监测值
# 0    2025-01-01 01:00:00  766.503
# 1    2025-01-01 02:00:00  766.512
# 2    2025-01-01 03:00:00  766.525
# 3    2025-01-01 04:00:00  766.542
# 4    2025-01-01 05:00:00  766.555
# ...                  ...      ...
# 3925 2025-07-08 22:00:00  768.085
# 3926 2025-07-08 23:00:00  768.082
# 3927 2025-07-09 00:00:00  768.100
# 3928 2025-07-09 01:00:00  768.111
# 3929 2025-07-09 02:00:00  768.057
#
# [3930 rows x 2 columns]

# %%
# 单步滚动预测函数 - 根据需求实现
def rolling_forecast_with_update(model, scaler, original_data, lookback, forecast_steps):
    """
    使用单步LSTM模型实现滚动预测并更新原数据集
    
    参数:
    model: 训练好的LSTM模型
    scaler: 用于归一化和反归一化的缩放器
    original_data: 原始数据集 (DataFrame，包含时间和监测值两列)
    lookback: 模型输入序列长度
    forecast_steps: 需要预测的未来步数
    
    返回:
    updated_data: 包含预测值的更新后的数据集
    """
    model.eval()
    
    # 确保数据格式正确
    time_column = original_data.columns[0]  # 假设第一列是时间
    value_column = original_data.columns[1]  # 假设第二列是监测值
    
    # 复制原始数据，避免修改原始数据
    data = original_data.copy()
    
    # 提取最后lookback个时间步的数据作为初始输入
    last_sequence = data[value_column].values[-lookback:].reshape(1, lookback, 1)
    
    # 归一化
    last_sequence_scaled = scaler.transform(last_sequence.reshape(-1, 1)).reshape(1, lookback, 1)
    
    # 转换为张量
    last_sequence_tensor = torch.FloatTensor(last_sequence_scaled)
    
    # 预测未来steps步
    with torch.no_grad():
        for i in range(forecast_steps):
            # 预测下一个时间步
            pred = model(last_sequence_tensor)
            pred_value = pred.item()
            
            # 反归一化预测值
            pred_value_actual = scaler.inverse_transform([[pred_value]])[0, 0]
            
            # 生成下一个时间戳（假设时间间隔均匀）
            last_time = pd.to_datetime(data[time_column].iloc[-1])
            time_delta = pd.to_datetime(data[time_column].iloc[-1]) - pd.to_datetime(data[time_column].iloc[-2])
            next_time = last_time + time_delta
            
            # 创建新的预测行
            new_row = pd.DataFrame({time_column: [next_time], value_column: [pred_value_actual]})
            
            # 将新行添加到数据集中
            data = pd.concat([data, new_row], ignore_index=True)
            
            # 更新输入序列：移除第一个时间步，添加新预测值
            new_sequence = np.roll(last_sequence_scaled, -1, axis=1)
            new_sequence[0, -1, 0] = pred_value
            last_sequence_scaled = new_sequence
            last_sequence_tensor = torch.FloatTensor(last_sequence_scaled)
    
    return data

# %%
# target为要输入的数据,lookback为序列长度
def split_data(target, lookback):
    data_raw = target.to_numpy() 
    data = []
    
    # you can free play（seq_length）
    for index in range(len(data_raw) - lookback + 1 ): 
        data.append(data_raw[index: index + lookback])
    
    data = np.array(data);

    # 设置测试集天数为最近30天的数据
    test_set_size = 0
    train_set_size = data.shape[0] - (test_set_size)
    
    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]
    
    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size:,-1,:]
    
    return [x_train, y_train, x_test, y_test]

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
# 模型超参数
input_dim = 1
hidden_dim = 50
num_layers = 3
output_dim = 1
lookback = 50
num_epochs = 500

# 该目录用于保存最优模型参数
os.makedirs('models', exist_ok=True)
# 该目录用于保存最优模型训练数据标准化格式
os.makedirs('scalers', exist_ok=True)


# 提取标签
target = df[['监测值']].copy()

#归一化
scaler = MinMaxScaler(feature_range=(-1, 1))
target['监测值'] = scaler.fit_transform(target['监测值'].values.reshape(-1,1))

best_scaler_path = 'scalers/' + '水地8-12_scaler.pkl'
print('模型标准化格式保存路径：',best_scaler_path)

# 保存标准化参数
joblib.dump(scaler, best_scaler_path)

#划分训练集、验证集、测试集
x_train, y_train , _ , _ = split_data(target, lookback)

print('x_train shape:',x_train.shape)
print('y_trian shape:',y_train.shape)
# Out:
# 模型标准化格式保存路径： scalers/水地8-12_scaler.pkl
# x_train shape: (3881, 49, 1)
# y_trian shape: (3881, 1)

# %%
# 转换成张量,神经网络模型的数据要求为张量类型
x_train = torch.from_numpy(x_train).type(torch.Tensor)
y_train_lstm = torch.from_numpy(y_train).type(torch.Tensor)

# 模型实例化准备开始训练
model = LSTM(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss()
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

import time

hist = np.zeros(num_epochs)
best_train_loss = float('inf')  # 用于保存验证集上的最佳损失
best_model_path = 'models/' + '水地8-12_model.pth'  # 最佳模型保存路径
print('最优模型参数保存路径：',best_model_path)

start_time = time.time()
lstm = []

for t in range(num_epochs):
    # 训练模式
    model.train()
    
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_lstm)
    hist[t] = loss.item()
    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

    # 验证模式
    model.eval()
    with torch.no_grad():  # 禁用梯度计算
        
        # 反归一化
        y_train_pred_1 = scaler.inverse_transform(y_train_pred.detach().numpy())
        y_train_1 = scaler.inverse_transform(y_train_lstm.detach().numpy())
        # 计算真实MSE
        train_loss = math.sqrt(mean_squared_error(y_train_pred_1[:, 0], y_train_1[:, 0]))
        print("Epoch ", t, "Train RMSE: ", train_loss)

        # 如果验证损失更好，则保存模型
        if train_loss < best_train_loss:
            best_train_loss = train_loss
            torch.save(model.state_dict(), best_model_path)
            print(f"Best model saved at epoch {t} with Train RMSE: {best_train_loss}")
    
training_time = time.time()-start_time
print("Training time: {}".format(training_time))
# Out:
# 最优模型参数保存路径： models/水地8-12_model.pth
# Epoch  0 Train RMSE:  2.0199635262548434
# Best model saved at epoch 0 with Train RMSE: 2.0199635262548434
# Epoch  1 Train RMSE:  1.587294050058756
# Best model saved at epoch 1 with Train RMSE: 1.587294050058756
# Epoch  2 Train RMSE:  1.122241293526892
# Best model saved at epoch 2 with Train RMSE: 1.122241293526892
# Epoch  3 Train RMSE:  1.6067941953505303
# Epoch  4 Train RMSE:  1.1060369534277403
# Best model saved at epoch 4 with Train RMSE: 1.1060369534277403
# Epoch  5 Train RMSE:  1.2769922361922041
# Epoch  6 Train RMSE:  1.3219305202647413
# Epoch  7 Train RMSE:  1.2943816057641724
# Epoch  8 Train RMSE:  1.2291777119975407
# Epoch  9 Train RMSE:  1.1440577129564995
# Epoch  10 Train RMSE:  1.0581848931528572
# Best model saved at epoch 10 with Train RMSE: 1.0581848931528572
# Epoch  11 Train RMSE:  0.9934841604155612
# Best model saved at epoch 11 with Train RMSE: 0.9934841604155612
# Epoch  12 Train RMSE:  0.9370446052763587
# Best model saved at epoch 12 with Train RMSE: 0.9370446052763587
# Epoch  13 Train RMSE:  0.8008970595564099
# Best model saved at epoch 13 with Train RMSE: 0.8008970595564099
# Epoch  14 Train RMSE:  0.6343589536394442
# Best model saved at epoch 14 with Train RMSE: 0.6343589536394442
# Epoch  15 Train RMSE:  0.8920469811409333
# Epoch  16 Train RMSE:  0.5755073206309171
# Best model saved at epoch 16 with Train RMSE: 0.5755073206309171
# Epoch  17 Train RMSE:  0.5579572399002303
# Best model saved at epoch 17 with Train RMSE: 0.5579572399002303
# Epoch  18 Train RMSE:  0.5869699410292057
# Epoch  19 Train RMSE:  0.6010777638359485
# Epoch  20 Train RMSE:  0.5952445845023149
# Epoch  21 Train RMSE:  0.5683794050849263
# Epoch  22 Train RMSE:  0.52251187370352
# Best model saved at epoch 22 with Train RMSE: 0.52251187370352
# Epoch  23 Train RMSE:  0.4594234395600722
# Best model saved at epoch 23 with Train RMSE: 0.4594234395600722
# Epoch  24 Train RMSE:  0.3768088899896011
# Best model saved at epoch 24 with Train RMSE: 0.3768088899896011
# Epoch  25 Train RMSE:  0.2741826802628571
# Best model saved at epoch 25 with Train RMSE: 0.2741826802628571
# Epoch  26 Train RMSE:  0.2199796363633956
# Best model saved at epoch 26 with Train RMSE: 0.2199796363633956
# Epoch  27 Train RMSE:  0.30368841645863437
# Epoch  28 Train RMSE:  0.33696498762406063
# Epoch  29 Train RMSE:  0.32390011216203207
# Epoch  30 Train RMSE:  0.21611774886417986
# Best model saved at epoch 30 with Train RMSE: 0.21611774886417986
# Epoch  31 Train RMSE:  0.1622920902472744
# Best model saved at epoch 31 with Train RMSE: 0.1622920902472744
# Epoch  32 Train RMSE:  0.1560479407350009
# Best model saved at epoch 32 with Train RMSE: 0.1560479407350009
# Epoch  33 Train RMSE:  0.17016268252114464
# Epoch  34 Train RMSE:  0.2136549920311061
# Epoch  35 Train RMSE:  0.21499497553310487
# Epoch  36 Train RMSE:  0.19034975770830187
# Epoch  37 Train RMSE:  0.17122994558698904
# Epoch  38 Train RMSE:  0.1411583046547202
# Best model saved at epoch 38 with Train RMSE: 0.1411583046547202
# Epoch  39 Train RMSE:  0.1249388306677116
# Best model saved at epoch 39 with Train RMSE: 0.1249388306677116
# Epoch  40 Train RMSE:  0.14924299507499725
# Epoch  41 Train RMSE:  0.13870318153417152
# Epoch  42 Train RMSE:  0.10905403488284189
# Best model saved at epoch 42 with Train RMSE: 0.10905403488284189
# Epoch  43 Train RMSE:  0.09949142353916302
# Best model saved at epoch 43 with Train RMSE: 0.09949142353916302
# Epoch  44 Train RMSE:  0.08777517047082975
# Best model saved at epoch 44 with Train RMSE: 0.08777517047082975
# Epoch  45 Train RMSE:  0.12303393916601058
# Epoch  46 Train RMSE:  0.12273095461852639
# Epoch  47 Train RMSE:  0.13049903763629966
# Epoch  48 Train RMSE:  0.10955103264295407
# Epoch  49 Train RMSE:  0.09143549214998771
# Epoch  50 Train RMSE:  0.07478582365964104
# Best model saved at epoch 50 with Train RMSE: 0.07478582365964104
# Epoch  51 Train RMSE:  0.0691723909520376
# Best model saved at epoch 51 with Train RMSE: 0.0691723909520376
# Epoch  52 Train RMSE:  0.08904494857176878
# Epoch  53 Train RMSE:  0.09171436030428906
# Epoch  54 Train RMSE:  0.0913466053140252
# Epoch  55 Train RMSE:  0.08393821445773135
# Epoch  56 Train RMSE:  0.07507695134621976
# Epoch  57 Train RMSE:  0.08002094809441919
# Epoch  58 Train RMSE:  0.07958181317308469
# Epoch  59 Train RMSE:  0.07756973772050191
# Epoch  60 Train RMSE:  0.0741830727506337
# Epoch  61 Train RMSE:  0.06410275581383541
# Best model saved at epoch 61 with Train RMSE: 0.06410275581383541
# Epoch  62 Train RMSE:  0.06456491860893727
# Epoch  63 Train RMSE:  0.06574542811652129
# Epoch  64 Train RMSE:  0.0709880588187745
# Epoch  65 Train RMSE:  0.07383296486466247
# Epoch  66 Train RMSE:  0.06959044061426753
# Epoch  67 Train RMSE:  0.06642657908448694
# Epoch  68 Train RMSE:  0.06079253037798414
# Best model saved at epoch 68 with Train RMSE: 0.06079253037798414
# Epoch  69 Train RMSE:  0.06156924979245486
# Epoch  70 Train RMSE:  0.06268248144505902
# Epoch  71 Train RMSE:  0.06328726198342652
# Epoch  72 Train RMSE:  0.0636052660860074
# Epoch  73 Train RMSE:  0.06101171997251533
# Epoch  74 Train RMSE:  0.06103030566968432
# Epoch  75 Train RMSE:  0.06094426062568252
# Epoch  76 Train RMSE:  0.061575691421279485
# Epoch  77 Train RMSE:  0.061598992502742714
# Epoch  78 Train RMSE:  0.05931317811119557
# Best model saved at epoch 78 with Train RMSE: 0.05931317811119557
# Epoch  79 Train RMSE:  0.058342196979321186
# Best model saved at epoch 79 with Train RMSE: 0.058342196979321186
# Epoch  80 Train RMSE:  0.057435675182400926
# Best model saved at epoch 80 with Train RMSE: 0.057435675182400926
# Epoch  81 Train RMSE:  0.05847257561684148
# Epoch  82 Train RMSE:  0.05931078746675379
# Epoch  83 Train RMSE:  0.059221599392040525
# Epoch  84 Train RMSE:  0.05880692367500795
# Epoch  85 Train RMSE:  0.05762092731752553
# Epoch  86 Train RMSE:  0.05759994402365212
# Epoch  87 Train RMSE:  0.057402428753177595
# Best model saved at epoch 87 with Train RMSE: 0.057402428753177595
# Epoch  88 Train RMSE:  0.057646259150387395
# Epoch  89 Train RMSE:  0.05725547634571151
# Best model saved at epoch 89 with Train RMSE: 0.05725547634571151
# Epoch  90 Train RMSE:  0.05685890207371767
# Best model saved at epoch 90 with Train RMSE: 0.05685890207371767
# Epoch  91 Train RMSE:  0.05682017584642279
# Best model saved at epoch 91 with Train RMSE: 0.05682017584642279
# Epoch  92 Train RMSE:  0.05688210509795178
# Epoch  93 Train RMSE:  0.05720709682850255
# Epoch  94 Train RMSE:  0.05690789877924094
# Epoch  95 Train RMSE:  0.05662401547744474
# Best model saved at epoch 95 with Train RMSE: 0.05662401547744474
# Epoch  96 Train RMSE:  0.05615934867288856
# Best model saved at epoch 96 with Train RMSE: 0.05615934867288856
# Epoch  97 Train RMSE:  0.05611282077245852
# Best model saved at epoch 97 with Train RMSE: 0.05611282077245852
# Epoch  98 Train RMSE:  0.05618423509964398
# Epoch  99 Train RMSE:  0.05622091667342798
# Epoch  100 Train RMSE:  0.05614284559442624
# Epoch  101 Train RMSE:  0.055915688342630596
# Best model saved at epoch 101 with Train RMSE: 0.055915688342630596
# Epoch  102 Train RMSE:  0.055869770166523884
# Best model saved at epoch 102 with Train RMSE: 0.055869770166523884
# Epoch  103 Train RMSE:  0.055783645273921045
# Best model saved at epoch 103 with Train RMSE: 0.055783645273921045
# Epoch  104 Train RMSE:  0.055791207715008784
# Epoch  105 Train RMSE:  0.05560383131365116
# Best model saved at epoch 105 with Train RMSE: 0.05560383131365116
# Epoch  106 Train RMSE:  0.05547879994377792
# Best model saved at epoch 106 with Train RMSE: 0.05547879994377792
# Epoch  107 Train RMSE:  0.05534159170422034
# Best model saved at epoch 107 with Train RMSE: 0.05534159170422034
# Epoch  108 Train RMSE:  0.05535665547543925
# Epoch  109 Train RMSE:  0.055344092801237005
# Epoch  110 Train RMSE:  0.05529072907242952
# Best model saved at epoch 110 with Train RMSE: 0.05529072907242952
# Epoch  111 Train RMSE:  0.05516345806409269
# Best model saved at epoch 111 with Train RMSE: 0.05516345806409269
# Epoch  112 Train RMSE:  0.05503919879606765
# Best model saved at epoch 112 with Train RMSE: 0.05503919879606765
# Epoch  113 Train RMSE:  0.05497011320929678
# Best model saved at epoch 113 with Train RMSE: 0.05497011320929678
# Epoch  114 Train RMSE:  0.0549119935398281
# Best model saved at epoch 114 with Train RMSE: 0.0549119935398281
# Epoch  115 Train RMSE:  0.054860548003609094
# Best model saved at epoch 115 with Train RMSE: 0.054860548003609094
# Epoch  116 Train RMSE:  0.05476099210657446
# Best model saved at epoch 116 with Train RMSE: 0.05476099210657446
# Epoch  117 Train RMSE:  0.05469111234791518
# Best model saved at epoch 117 with Train RMSE: 0.05469111234791518
# Epoch  118 Train RMSE:  0.05462003702034808
# Best model saved at epoch 118 with Train RMSE: 0.05462003702034808
# Epoch  119 Train RMSE:  0.05458393465860815
# Best model saved at epoch 119 with Train RMSE: 0.05458393465860815
# Epoch  120 Train RMSE:  0.054503098031373015
# Best model saved at epoch 120 with Train RMSE: 0.054503098031373015
# Epoch  121 Train RMSE:  0.054421891055295046
# Best model saved at epoch 121 with Train RMSE: 0.054421891055295046
# Epoch  122 Train RMSE:  0.05432107261014526
# Best model saved at epoch 122 with Train RMSE: 0.05432107261014526
# Epoch  123 Train RMSE:  0.054259977136169965
# Best model saved at epoch 123 with Train RMSE: 0.054259977136169965
# Epoch  124 Train RMSE:  0.05419774955614017
# Best model saved at epoch 124 with Train RMSE: 0.05419774955614017
# Epoch  125 Train RMSE:  0.05414596510295079
# Best model saved at epoch 125 with Train RMSE: 0.05414596510295079
# Epoch  126 Train RMSE:  0.054066204832313836
# Best model saved at epoch 126 with Train RMSE: 0.054066204832313836
# Epoch  127 Train RMSE:  0.05399367518370128
# Best model saved at epoch 127 with Train RMSE: 0.05399367518370128
# Epoch  128 Train RMSE:  0.05391768631352976
# Best model saved at epoch 128 with Train RMSE: 0.05391768631352976
# Epoch  129 Train RMSE:  0.05385713620425675
# Best model saved at epoch 129 with Train RMSE: 0.05385713620425675
# Epoch  130 Train RMSE:  0.053783495617714054
# Best model saved at epoch 130 with Train RMSE: 0.053783495617714054
# Epoch  131 Train RMSE:  0.0537127277769484
# Best model saved at epoch 131 with Train RMSE: 0.0537127277769484
# Epoch  132 Train RMSE:  0.053634092238564954
# Best model saved at epoch 132 with Train RMSE: 0.053634092238564954
# Epoch  133 Train RMSE:  0.05357142231826235
# Best model saved at epoch 133 with Train RMSE: 0.05357142231826235
# Epoch  134 Train RMSE:  0.05350530883455698
# Best model saved at epoch 134 with Train RMSE: 0.05350530883455698
# Epoch  135 Train RMSE:  0.05344072124116629
# Best model saved at epoch 135 with Train RMSE: 0.05344072124116629
# Epoch  136 Train RMSE:  0.05336562255892988
# Best model saved at epoch 136 with Train RMSE: 0.05336562255892988
# Epoch  137 Train RMSE:  0.05329310059903343
# Best model saved at epoch 137 with Train RMSE: 0.05329310059903343
# Epoch  138 Train RMSE:  0.05322120603282982
# Best model saved at epoch 138 with Train RMSE: 0.05322120603282982
# Epoch  139 Train RMSE:  0.05315589873987249
# Best model saved at epoch 139 with Train RMSE: 0.05315589873987249
# Epoch  140 Train RMSE:  0.05308568679674583
# Best model saved at epoch 140 with Train RMSE: 0.05308568679674583
# Epoch  141 Train RMSE:  0.0530167059651855
# Best model saved at epoch 141 with Train RMSE: 0.0530167059651855
# Epoch  142 Train RMSE:  0.05294470213380222
# Best model saved at epoch 142 with Train RMSE: 0.05294470213380222
# Epoch  143 Train RMSE:  0.05287705431533852
# Best model saved at epoch 143 with Train RMSE: 0.05287705431533852
# Epoch  144 Train RMSE:  0.052808786362514654
# Best model saved at epoch 144 with Train RMSE: 0.052808786362514654
# Epoch  145 Train RMSE:  0.0527387215447813
# Best model saved at epoch 145 with Train RMSE: 0.0527387215447813
# Epoch  146 Train RMSE:  0.05266686374286279
# Best model saved at epoch 146 with Train RMSE: 0.05266686374286279
# Epoch  147 Train RMSE:  0.05259670504245697
# Best model saved at epoch 147 with Train RMSE: 0.05259670504245697
# Epoch  148 Train RMSE:  0.052527749162358923
# Best model saved at epoch 148 with Train RMSE: 0.052527749162358923
# Epoch  149 Train RMSE:  0.052459324008076985
# Best model saved at epoch 149 with Train RMSE: 0.052459324008076985
# Epoch  150 Train RMSE:  0.05239009842421692
# Best model saved at epoch 150 with Train RMSE: 0.05239009842421692
# Epoch  151 Train RMSE:  0.05231890106376455
# Best model saved at epoch 151 with Train RMSE: 0.05231890106376455
# Epoch  152 Train RMSE:  0.0522493290122311
# Best model saved at epoch 152 with Train RMSE: 0.0522493290122311
# Epoch  153 Train RMSE:  0.05217953256717417
# Best model saved at epoch 153 with Train RMSE: 0.05217953256717417
# Epoch  154 Train RMSE:  0.052111108149140745
# Best model saved at epoch 154 with Train RMSE: 0.052111108149140745
# Epoch  155 Train RMSE:  0.052039710293528975
# Best model saved at epoch 155 with Train RMSE: 0.052039710293528975
# Epoch  156 Train RMSE:  0.05197085986711749
# Best model saved at epoch 156 with Train RMSE: 0.05197085986711749
# Epoch  157 Train RMSE:  0.05190115548619181
# Best model saved at epoch 157 with Train RMSE: 0.05190115548619181
# Epoch  158 Train RMSE:  0.0518321883930662
# Best model saved at epoch 158 with Train RMSE: 0.0518321883930662
# Epoch  159 Train RMSE:  0.05176262338340216
# Best model saved at epoch 159 with Train RMSE: 0.05176262338340216
# Epoch  160 Train RMSE:  0.05169323275145551
# Best model saved at epoch 160 with Train RMSE: 0.05169323275145551
# Epoch  161 Train RMSE:  0.05162322341272774
# Best model saved at epoch 161 with Train RMSE: 0.05162322341272774
# Epoch  162 Train RMSE:  0.05155355708280001
# Best model saved at epoch 162 with Train RMSE: 0.05155355708280001
# Epoch  163 Train RMSE:  0.05148369246712039
# Best model saved at epoch 163 with Train RMSE: 0.05148369246712039
# Epoch  164 Train RMSE:  0.05141532468195671
# Best model saved at epoch 164 with Train RMSE: 0.05141532468195671
# Epoch  165 Train RMSE:  0.05134607912995575
# Best model saved at epoch 165 with Train RMSE: 0.05134607912995575
# Epoch  166 Train RMSE:  0.05127518940539091
# Best model saved at epoch 166 with Train RMSE: 0.05127518940539091
# Epoch  167 Train RMSE:  0.051206177214542015
# Best model saved at epoch 167 with Train RMSE: 0.051206177214542015
# Epoch  168 Train RMSE:  0.0511371902678366
# Best model saved at epoch 168 with Train RMSE: 0.0511371902678366
# Epoch  169 Train RMSE:  0.05106769295790611
# Best model saved at epoch 169 with Train RMSE: 0.05106769295790611
# Epoch  170 Train RMSE:  0.05099820594694124
# Best model saved at epoch 170 with Train RMSE: 0.05099820594694124
# Epoch  171 Train RMSE:  0.05092961846411459
# Best model saved at epoch 171 with Train RMSE: 0.05092961846411459
# Epoch  172 Train RMSE:  0.050860185437257
# Best model saved at epoch 172 with Train RMSE: 0.050860185437257
# Epoch  173 Train RMSE:  0.050791308433893026
# Best model saved at epoch 173 with Train RMSE: 0.050791308433893026
# Epoch  174 Train RMSE:  0.05072270282835763
# Best model saved at epoch 174 with Train RMSE: 0.05072270282835763
# Epoch  175 Train RMSE:  0.050653965233532924
# Best model saved at epoch 175 with Train RMSE: 0.050653965233532924
# Epoch  176 Train RMSE:  0.050584828151041886
# Best model saved at epoch 176 with Train RMSE: 0.050584828151041886
# Epoch  177 Train RMSE:  0.05051615644630265
# Best model saved at epoch 177 with Train RMSE: 0.05051615644630265
# Epoch  178 Train RMSE:  0.050446719729105347
# Best model saved at epoch 178 with Train RMSE: 0.050446719729105347
# Epoch  179 Train RMSE:  0.05037873325568134
# Best model saved at epoch 179 with Train RMSE: 0.05037873325568134
# Epoch  180 Train RMSE:  0.05031040963278924
# Best model saved at epoch 180 with Train RMSE: 0.05031040963278924
# Epoch  181 Train RMSE:  0.05024186102289925
# Best model saved at epoch 181 with Train RMSE: 0.05024186102289925
# Epoch  182 Train RMSE:  0.050173687451288765
# Best model saved at epoch 182 with Train RMSE: 0.050173687451288765
# Epoch  183 Train RMSE:  0.050105444356689795
# Best model saved at epoch 183 with Train RMSE: 0.050105444356689795
# Epoch  184 Train RMSE:  0.05003793411784264
# Best model saved at epoch 184 with Train RMSE: 0.05003793411784264
# Epoch  185 Train RMSE:  0.04996997622866458
# Best model saved at epoch 185 with Train RMSE: 0.04996997622866458
# Epoch  186 Train RMSE:  0.04990203777077588
# Best model saved at epoch 186 with Train RMSE: 0.04990203777077588
# Epoch  187 Train RMSE:  0.04983341800174237
# Best model saved at epoch 187 with Train RMSE: 0.04983341800174237
# Epoch  188 Train RMSE:  0.04976612589732257
# Best model saved at epoch 188 with Train RMSE: 0.04976612589732257
# Epoch  189 Train RMSE:  0.04969889962135042
# Best model saved at epoch 189 with Train RMSE: 0.04969889962135042
# Epoch  190 Train RMSE:  0.049631343036354726
# Best model saved at epoch 190 with Train RMSE: 0.049631343036354726
# Epoch  191 Train RMSE:  0.04956447181756927
# Best model saved at epoch 191 with Train RMSE: 0.04956447181756927
# Epoch  192 Train RMSE:  0.04949681172374392
# Best model saved at epoch 192 with Train RMSE: 0.04949681172374392
# Epoch  193 Train RMSE:  0.04942985742104754
# Best model saved at epoch 193 with Train RMSE: 0.04942985742104754
# Epoch  194 Train RMSE:  0.049363291048461155
# Best model saved at epoch 194 with Train RMSE: 0.049363291048461155
# Epoch  195 Train RMSE:  0.04929675050453752
# Best model saved at epoch 195 with Train RMSE: 0.04929675050453752
# Epoch  196 Train RMSE:  0.04923035649416447
# Best model saved at epoch 196 with Train RMSE: 0.04923035649416447
# Epoch  197 Train RMSE:  0.04916364076607167
# Best model saved at epoch 197 with Train RMSE: 0.04916364076607167
# Epoch  198 Train RMSE:  0.04909806024326151
# Best model saved at epoch 198 with Train RMSE: 0.04909806024326151
# Epoch  199 Train RMSE:  0.04903147791091679
# Best model saved at epoch 199 with Train RMSE: 0.04903147791091679
# Epoch  200 Train RMSE:  0.04896649068018717
# Best model saved at epoch 200 with Train RMSE: 0.04896649068018717
# Epoch  201 Train RMSE:  0.04890037436579675
# Best model saved at epoch 201 with Train RMSE: 0.04890037436579675
# Epoch  202 Train RMSE:  0.048835303255776626
# Best model saved at epoch 202 with Train RMSE: 0.048835303255776626
# Epoch  203 Train RMSE:  0.048769718046827455
# Best model saved at epoch 203 with Train RMSE: 0.048769718046827455
# Epoch  204 Train RMSE:  0.04870491456726639
# Best model saved at epoch 204 with Train RMSE: 0.04870491456726639
# Epoch  205 Train RMSE:  0.04864028323675658
# Best model saved at epoch 205 with Train RMSE: 0.04864028323675658
# Epoch  206 Train RMSE:  0.04857488527826175
# Best model saved at epoch 206 with Train RMSE: 0.04857488527826175
# Epoch  207 Train RMSE:  0.048510282290639604
# Best model saved at epoch 207 with Train RMSE: 0.048510282290639604
# Epoch  208 Train RMSE:  0.048446011276169994
# Best model saved at epoch 208 with Train RMSE: 0.048446011276169994
# Epoch  209 Train RMSE:  0.048382853149484456
# Best model saved at epoch 209 with Train RMSE: 0.048382853149484456
# Epoch  210 Train RMSE:  0.04831801509252654
# Best model saved at epoch 210 with Train RMSE: 0.04831801509252654
# Epoch  211 Train RMSE:  0.04825440717292155
# Best model saved at epoch 211 with Train RMSE: 0.04825440717292155
# Epoch  212 Train RMSE:  0.04819064040857549
# Best model saved at epoch 212 with Train RMSE: 0.04819064040857549
# Epoch  213 Train RMSE:  0.048127459193847415
# Best model saved at epoch 213 with Train RMSE: 0.048127459193847415
# Epoch  214 Train RMSE:  0.04806447588684319
# Best model saved at epoch 214 with Train RMSE: 0.04806447588684319
# Epoch  215 Train RMSE:  0.04800058049668029
# Best model saved at epoch 215 with Train RMSE: 0.04800058049668029
# Epoch  216 Train RMSE:  0.04793786032838442
# Best model saved at epoch 216 with Train RMSE: 0.04793786032838442
# Epoch  217 Train RMSE:  0.04787557106682816
# Best model saved at epoch 217 with Train RMSE: 0.04787557106682816
# Epoch  218 Train RMSE:  0.04781376552621077
# Best model saved at epoch 218 with Train RMSE: 0.04781376552621077
# Epoch  219 Train RMSE:  0.04775162157003448
# Best model saved at epoch 219 with Train RMSE: 0.04775162157003448
# Epoch  220 Train RMSE:  0.04769019975447645
# Best model saved at epoch 220 with Train RMSE: 0.04769019975447645
# Epoch  221 Train RMSE:  0.04762838097912077
# Best model saved at epoch 221 with Train RMSE: 0.04762838097912077
# Epoch  222 Train RMSE:  0.047566650734281186
# Best model saved at epoch 222 with Train RMSE: 0.047566650734281186
# Epoch  223 Train RMSE:  0.04750607781049661
# Best model saved at epoch 223 with Train RMSE: 0.04750607781049661
# Epoch  224 Train RMSE:  0.04744418107449898
# Best model saved at epoch 224 with Train RMSE: 0.04744418107449898
# Epoch  225 Train RMSE:  0.04738378818211871
# Best model saved at epoch 225 with Train RMSE: 0.04738378818211871
# Epoch  226 Train RMSE:  0.04732332805782486
# Best model saved at epoch 226 with Train RMSE: 0.04732332805782486
# Epoch  227 Train RMSE:  0.0472635566243095
# Best model saved at epoch 227 with Train RMSE: 0.0472635566243095
# Epoch  228 Train RMSE:  0.047203591126303214
# Best model saved at epoch 228 with Train RMSE: 0.047203591126303214
# Epoch  229 Train RMSE:  0.04714291224938326
# Best model saved at epoch 229 with Train RMSE: 0.04714291224938326
# Epoch  230 Train RMSE:  0.04708371288240118
# Best model saved at epoch 230 with Train RMSE: 0.04708371288240118
# Epoch  231 Train RMSE:  0.04702395376215802
# Best model saved at epoch 231 with Train RMSE: 0.04702395376215802
# Epoch  232 Train RMSE:  0.04696509276581614
# Best model saved at epoch 232 with Train RMSE: 0.04696509276581614
# Epoch  233 Train RMSE:  0.046906344047219564
# Best model saved at epoch 233 with Train RMSE: 0.046906344047219564
# Epoch  234 Train RMSE:  0.0468475763249787
# Best model saved at epoch 234 with Train RMSE: 0.0468475763249787
# Epoch  235 Train RMSE:  0.04678900599193616
# Best model saved at epoch 235 with Train RMSE: 0.04678900599193616
# Epoch  236 Train RMSE:  0.04673099003043239
# Best model saved at epoch 236 with Train RMSE: 0.04673099003043239
# Epoch  237 Train RMSE:  0.04667266000736268
# Best model saved at epoch 237 with Train RMSE: 0.04667266000736268
# Epoch  238 Train RMSE:  0.04661608007406069
# Best model saved at epoch 238 with Train RMSE: 0.04661608007406069
# Epoch  239 Train RMSE:  0.04655677092512707
# Best model saved at epoch 239 with Train RMSE: 0.04655677092512707
# Epoch  240 Train RMSE:  0.04650079603420712
# Best model saved at epoch 240 with Train RMSE: 0.04650079603420712
# Epoch  241 Train RMSE:  0.04644321464584364
# Best model saved at epoch 241 with Train RMSE: 0.04644321464584364
# Epoch  242 Train RMSE:  0.046386728788675925
# Best model saved at epoch 242 with Train RMSE: 0.046386728788675925
# Epoch  243 Train RMSE:  0.04632994289192715
# Best model saved at epoch 243 with Train RMSE: 0.04632994289192715
# Epoch  244 Train RMSE:  0.04627352757664933
# Best model saved at epoch 244 with Train RMSE: 0.04627352757664933
# Epoch  245 Train RMSE:  0.046217103850631616
# Best model saved at epoch 245 with Train RMSE: 0.046217103850631616
# Epoch  246 Train RMSE:  0.046161206335245536
# Best model saved at epoch 246 with Train RMSE: 0.046161206335245536
# Epoch  247 Train RMSE:  0.04610566019695416
# Best model saved at epoch 247 with Train RMSE: 0.04610566019695416
# Epoch  248 Train RMSE:  0.04604983976037392
# Best model saved at epoch 248 with Train RMSE: 0.04604983976037392
# Epoch  249 Train RMSE:  0.045994199624716854
# Best model saved at epoch 249 with Train RMSE: 0.045994199624716854
# Epoch  250 Train RMSE:  0.04593978450002522
# Best model saved at epoch 250 with Train RMSE: 0.04593978450002522
# Epoch  251 Train RMSE:  0.04588476951487715
# Best model saved at epoch 251 with Train RMSE: 0.04588476951487715
# Epoch  252 Train RMSE:  0.0458305114971084
# Best model saved at epoch 252 with Train RMSE: 0.0458305114971084
# Epoch  253 Train RMSE:  0.04577631378170713
# Best model saved at epoch 253 with Train RMSE: 0.04577631378170713
# Epoch  254 Train RMSE:  0.04572179720583684
# Best model saved at epoch 254 with Train RMSE: 0.04572179720583684
# Epoch  255 Train RMSE:  0.04566748576471291
# Best model saved at epoch 255 with Train RMSE: 0.04566748576471291
# Epoch  256 Train RMSE:  0.04561375026130169
# Best model saved at epoch 256 with Train RMSE: 0.04561375026130169
# Epoch  257 Train RMSE:  0.045559695857920066
# Best model saved at epoch 257 with Train RMSE: 0.045559695857920066
# Epoch  258 Train RMSE:  0.04550632169434551
# Best model saved at epoch 258 with Train RMSE: 0.04550632169434551
# Epoch  259 Train RMSE:  0.04545263385359823
# Best model saved at epoch 259 with Train RMSE: 0.04545263385359823
# Epoch  260 Train RMSE:  0.04539984668070237
# Best model saved at epoch 260 with Train RMSE: 0.04539984668070237
# Epoch  261 Train RMSE:  0.045346987790929674
# Best model saved at epoch 261 with Train RMSE: 0.045346987790929674
# Epoch  262 Train RMSE:  0.04529457611301392
# Best model saved at epoch 262 with Train RMSE: 0.04529457611301392
# Epoch  263 Train RMSE:  0.04524149387389802
# Best model saved at epoch 263 with Train RMSE: 0.04524149387389802
# Epoch  264 Train RMSE:  0.04518951114192961
# Best model saved at epoch 264 with Train RMSE: 0.04518951114192961
# Epoch  265 Train RMSE:  0.04513716162658673
# Best model saved at epoch 265 with Train RMSE: 0.04513716162658673
# Epoch  266 Train RMSE:  0.04508528840915324
# Best model saved at epoch 266 with Train RMSE: 0.04508528840915324
# Epoch  267 Train RMSE:  0.04503405082392193
# Best model saved at epoch 267 with Train RMSE: 0.04503405082392193
# Epoch  268 Train RMSE:  0.04498235632297976
# Best model saved at epoch 268 with Train RMSE: 0.04498235632297976
# Epoch  269 Train RMSE:  0.04493100394909085
# Best model saved at epoch 269 with Train RMSE: 0.04493100394909085
# Epoch  270 Train RMSE:  0.04487904549021856
# Best model saved at epoch 270 with Train RMSE: 0.04487904549021856
# Epoch  271 Train RMSE:  0.04482758255929867
# Best model saved at epoch 271 with Train RMSE: 0.04482758255929867
# Epoch  272 Train RMSE:  0.044776770259522806
# Best model saved at epoch 272 with Train RMSE: 0.044776770259522806
# Epoch  273 Train RMSE:  0.04472599393574844
# Best model saved at epoch 273 with Train RMSE: 0.04472599393574844
# Epoch  274 Train RMSE:  0.04467428433798194
# Best model saved at epoch 274 with Train RMSE: 0.04467428433798194
# Epoch  275 Train RMSE:  0.044625047980210615
# Best model saved at epoch 275 with Train RMSE: 0.044625047980210615
# Epoch  276 Train RMSE:  0.04457459504835589
# Best model saved at epoch 276 with Train RMSE: 0.04457459504835589
# Epoch  277 Train RMSE:  0.04452464186426238
# Best model saved at epoch 277 with Train RMSE: 0.04452464186426238
# Epoch  278 Train RMSE:  0.044474221613713324
# Best model saved at epoch 278 with Train RMSE: 0.044474221613713324
# Epoch  279 Train RMSE:  0.04442377820434583
# Best model saved at epoch 279 with Train RMSE: 0.04442377820434583
# Epoch  280 Train RMSE:  0.04437333254552395
# Best model saved at epoch 280 with Train RMSE: 0.04437333254552395
# Epoch  281 Train RMSE:  0.04432396411965492
# Best model saved at epoch 281 with Train RMSE: 0.04432396411965492
# Epoch  282 Train RMSE:  0.04427478254926245
# Best model saved at epoch 282 with Train RMSE: 0.04427478254926245
# Epoch  283 Train RMSE:  0.04422450387911215
# Best model saved at epoch 283 with Train RMSE: 0.04422450387911215
# Epoch  284 Train RMSE:  0.04417607726727288
# Best model saved at epoch 284 with Train RMSE: 0.04417607726727288
# Epoch  285 Train RMSE:  0.04412611484453156
# Best model saved at epoch 285 with Train RMSE: 0.04412611484453156
# Epoch  286 Train RMSE:  0.044077215656327724
# Best model saved at epoch 286 with Train RMSE: 0.044077215656327724
# Epoch  287 Train RMSE:  0.044028214565258836
# Best model saved at epoch 287 with Train RMSE: 0.044028214565258836
# Epoch  288 Train RMSE:  0.04397887696532245
# Best model saved at epoch 288 with Train RMSE: 0.04397887696532245
# Epoch  289 Train RMSE:  0.04393031606168541
# Best model saved at epoch 289 with Train RMSE: 0.04393031606168541
# Epoch  290 Train RMSE:  0.04388069196546781
# Best model saved at epoch 290 with Train RMSE: 0.04388069196546781
# Epoch  291 Train RMSE:  0.04383292131138141
# Best model saved at epoch 291 with Train RMSE: 0.04383292131138141
# Epoch  292 Train RMSE:  0.043784217141030014
# Best model saved at epoch 292 with Train RMSE: 0.043784217141030014
# Epoch  293 Train RMSE:  0.04373615079751907
# Best model saved at epoch 293 with Train RMSE: 0.04373615079751907
# Epoch  294 Train RMSE:  0.04368768249403339
# Best model saved at epoch 294 with Train RMSE: 0.04368768249403339
# Epoch  295 Train RMSE:  0.043640126048266836
# Best model saved at epoch 295 with Train RMSE: 0.043640126048266836
# Epoch  296 Train RMSE:  0.04359172189517127
# Best model saved at epoch 296 with Train RMSE: 0.04359172189517127
# Epoch  297 Train RMSE:  0.043543330773258296
# Best model saved at epoch 297 with Train RMSE: 0.043543330773258296
# Epoch  298 Train RMSE:  0.043495597763728036
# Best model saved at epoch 298 with Train RMSE: 0.043495597763728036
# Epoch  299 Train RMSE:  0.04344755374772613
# Best model saved at epoch 299 with Train RMSE: 0.04344755374772613
# Epoch  300 Train RMSE:  0.04339942301593459
# Best model saved at epoch 300 with Train RMSE: 0.04339942301593459
# Epoch  301 Train RMSE:  0.04335157720581358
# Best model saved at epoch 301 with Train RMSE: 0.04335157720581358
# Epoch  302 Train RMSE:  0.04330437480767855
# Best model saved at epoch 302 with Train RMSE: 0.04330437480767855
# Epoch  303 Train RMSE:  0.04325671183155694
# Best model saved at epoch 303 with Train RMSE: 0.04325671183155694
# Epoch  304 Train RMSE:  0.04320849110680823
# Best model saved at epoch 304 with Train RMSE: 0.04320849110680823
# Epoch  305 Train RMSE:  0.04316192520252832
# Best model saved at epoch 305 with Train RMSE: 0.04316192520252832
# Epoch  306 Train RMSE:  0.04311358091179894
# Best model saved at epoch 306 with Train RMSE: 0.04311358091179894
# Epoch  307 Train RMSE:  0.04306679885495001
# Best model saved at epoch 307 with Train RMSE: 0.04306679885495001
# Epoch  308 Train RMSE:  0.04302004034203029
# Best model saved at epoch 308 with Train RMSE: 0.04302004034203029
# Epoch  309 Train RMSE:  0.04297208231228962
# Best model saved at epoch 309 with Train RMSE: 0.04297208231228962
# Epoch  310 Train RMSE:  0.042925720994820095
# Best model saved at epoch 310 with Train RMSE: 0.042925720994820095
# Epoch  311 Train RMSE:  0.0428776846209757
# Best model saved at epoch 311 with Train RMSE: 0.0428776846209757
# Epoch  312 Train RMSE:  0.042830966991904564
# Best model saved at epoch 312 with Train RMSE: 0.042830966991904564
# Epoch  313 Train RMSE:  0.042784813289213346
# Best model saved at epoch 313 with Train RMSE: 0.042784813289213346
# Epoch  314 Train RMSE:  0.042737514726588
# Best model saved at epoch 314 with Train RMSE: 0.042737514726588
# Epoch  315 Train RMSE:  0.04269028920055958
# Best model saved at epoch 315 with Train RMSE: 0.04269028920055958
# Epoch  316 Train RMSE:  0.04264462613712568
# Best model saved at epoch 316 with Train RMSE: 0.04264462613712568
# Epoch  317 Train RMSE:  0.04259763787831956
# Best model saved at epoch 317 with Train RMSE: 0.04259763787831956
# Epoch  318 Train RMSE:  0.04255164694581761
# Best model saved at epoch 318 with Train RMSE: 0.04255164694581761
# Epoch  319 Train RMSE:  0.04250640598002282
# Best model saved at epoch 319 with Train RMSE: 0.04250640598002282
# Epoch  320 Train RMSE:  0.04246013116158659
# Best model saved at epoch 320 with Train RMSE: 0.04246013116158659
# Epoch  321 Train RMSE:  0.04241747405651351
# Best model saved at epoch 321 with Train RMSE: 0.04241747405651351
# Epoch  322 Train RMSE:  0.0423798946285928
# Best model saved at epoch 322 with Train RMSE: 0.0423798946285928
# Epoch  323 Train RMSE:  0.042353452509172704
# Best model saved at epoch 323 with Train RMSE: 0.042353452509172704
# Epoch  324 Train RMSE:  0.0423570269931545
# Epoch  325 Train RMSE:  0.042437945930114226
# Epoch  326 Train RMSE:  0.04271171920330362
# Epoch  327 Train RMSE:  0.043497194257824986
# Epoch  328 Train RMSE:  0.04550912797852041
# Epoch  329 Train RMSE:  0.050689628366771454
# Epoch  330 Train RMSE:  0.06151913067714343
# Epoch  331 Train RMSE:  0.08451117205283196
# Epoch  332 Train RMSE:  0.11344231057410016
# Epoch  333 Train RMSE:  0.15804648002842922
# Epoch  334 Train RMSE:  0.14379682685223683
# Epoch  335 Train RMSE:  0.10312645109196078
# Epoch  336 Train RMSE:  0.05083778333940235
# Epoch  337 Train RMSE:  0.10846108267409708
# Epoch  338 Train RMSE:  0.10444502791275286
# Epoch  339 Train RMSE:  0.04857991311732326
# Epoch  340 Train RMSE:  0.10647061248529677
# Epoch  341 Train RMSE:  0.08605423227623539
# Epoch  342 Train RMSE:  0.05880597938901441
# Epoch  343 Train RMSE:  0.10240076820897492
# Epoch  344 Train RMSE:  0.058569328861466714
# Epoch  345 Train RMSE:  0.07437660032742474
# Epoch  346 Train RMSE:  0.07630037509527131
# Epoch  347 Train RMSE:  0.04804274019809932
# Epoch  348 Train RMSE:  0.07613724447085204
# Epoch  349 Train RMSE:  0.045688639183199396
# Epoch  350 Train RMSE:  0.06969193619241744
# Epoch  351 Train RMSE:  0.053624838398087474
# Epoch  352 Train RMSE:  0.05784788458412861
# Epoch  353 Train RMSE:  0.058757315266486816
# Epoch  354 Train RMSE:  0.0468495096000531
# Epoch  355 Train RMSE:  0.06020625887515013
# Epoch  356 Train RMSE:  0.04345194245664808
# Epoch  357 Train RMSE:  0.05817374057324532
# Epoch  358 Train RMSE:  0.04634088962766717
# Epoch  359 Train RMSE:  0.05164368435357377
# Epoch  360 Train RMSE:  0.0498733771436283
# Epoch  361 Train RMSE:  0.045636665795290694
# Epoch  362 Train RMSE:  0.05147513534604297
# Epoch  363 Train RMSE:  0.043279799424576264
# Epoch  364 Train RMSE:  0.05081209291462805
# Epoch  365 Train RMSE:  0.043607358026314685
# Epoch  366 Train RMSE:  0.04785508999181492
# Epoch  367 Train RMSE:  0.04495993587809964
# Epoch  368 Train RMSE:  0.04467069330650582
# Epoch  369 Train RMSE:  0.0461867716240458
# Epoch  370 Train RMSE:  0.04267159033302889
# Epoch  371 Train RMSE:  0.046222000293273016
# Epoch  372 Train RMSE:  0.042214466512012355
# Best model saved at epoch 372 with Train RMSE: 0.042214466512012355
# Epoch  373 Train RMSE:  0.0447993733231984
# Epoch  374 Train RMSE:  0.04277994659401379
# Epoch  375 Train RMSE:  0.04308509788663482
# Epoch  376 Train RMSE:  0.0434533784702738
# Epoch  377 Train RMSE:  0.0419155852671348
# Best model saved at epoch 377 with Train RMSE: 0.0419155852671348
# Epoch  378 Train RMSE:  0.043535578121556034
# Epoch  379 Train RMSE:  0.041517848590139086
# Best model saved at epoch 379 with Train RMSE: 0.041517848590139086
# Epoch  380 Train RMSE:  0.04287981995947616
# Epoch  381 Train RMSE:  0.041700973797655985
# Epoch  382 Train RMSE:  0.04195658150078397
# Epoch  383 Train RMSE:  0.042026507137061575
# Epoch  384 Train RMSE:  0.041240787938237565
# Best model saved at epoch 384 with Train RMSE: 0.041240787938237565
# Epoch  385 Train RMSE:  0.04203078940867726
# Epoch  386 Train RMSE:  0.0409838419908491
# Best model saved at epoch 386 with Train RMSE: 0.0409838419908491
# Epoch  387 Train RMSE:  0.04157884648070529
# Epoch  388 Train RMSE:  0.041073473088275206
# Epoch  389 Train RMSE:  0.04099401262215996
# Epoch  390 Train RMSE:  0.04117570304175584
# Epoch  391 Train RMSE:  0.040620303684911145
# Best model saved at epoch 391 with Train RMSE: 0.040620303684911145
# Epoch  392 Train RMSE:  0.04103558769798149
# Epoch  393 Train RMSE:  0.04054335054016958
# Best model saved at epoch 393 with Train RMSE: 0.04054335054016958
# Epoch  394 Train RMSE:  0.04067272371393242
# Epoch  395 Train RMSE:  0.04058916478364246
# Epoch  396 Train RMSE:  0.04033332942693011
# Best model saved at epoch 396 with Train RMSE: 0.04033332942693011
# Epoch  397 Train RMSE:  0.0405349279109416
# Epoch  398 Train RMSE:  0.04019146791038711
# Best model saved at epoch 398 with Train RMSE: 0.04019146791038711
# Epoch  399 Train RMSE:  0.040311140429780255
# Epoch  400 Train RMSE:  0.04018239788820966
# Best model saved at epoch 400 with Train RMSE: 0.04018239788820966
# Epoch  401 Train RMSE:  0.04004727982888718
# Best model saved at epoch 401 with Train RMSE: 0.04004727982888718
# Epoch  402 Train RMSE:  0.04012887465034696
# Epoch  403 Train RMSE:  0.039896138603137725
# Best model saved at epoch 403 with Train RMSE: 0.039896138603137725
# Epoch  404 Train RMSE:  0.039956503453835175
# Epoch  405 Train RMSE:  0.039847505967434846
# Best model saved at epoch 405 with Train RMSE: 0.039847505967434846
# Epoch  406 Train RMSE:  0.039751831081114755
# Best model saved at epoch 406 with Train RMSE: 0.039751831081114755
# Epoch  407 Train RMSE:  0.039777190113641905
# Epoch  408 Train RMSE:  0.03961691360711829
# Best model saved at epoch 408 with Train RMSE: 0.03961691360711829
# Epoch  409 Train RMSE:  0.03963042998921414
# Epoch  410 Train RMSE:  0.039547796489977624
# Best model saved at epoch 410 with Train RMSE: 0.039547796489977624
# Epoch  411 Train RMSE:  0.039463212652197585
# Best model saved at epoch 411 with Train RMSE: 0.039463212652197585
# Epoch  412 Train RMSE:  0.03946448111922085
# Epoch  413 Train RMSE:  0.03934810358897313
# Best model saved at epoch 413 with Train RMSE: 0.03934810358897313
# Epoch  414 Train RMSE:  0.03932889758398075
# Best model saved at epoch 414 with Train RMSE: 0.03932889758398075
# Epoch  415 Train RMSE:  0.0392698150999412
# Best model saved at epoch 415 with Train RMSE: 0.0392698150999412
# Epoch  416 Train RMSE:  0.039187933281354254
# Best model saved at epoch 416 with Train RMSE: 0.039187933281354254
# Epoch  417 Train RMSE:  0.03917306808451021
# Best model saved at epoch 417 with Train RMSE: 0.03917306808451021
# Epoch  418 Train RMSE:  0.0390866413619222
# Best model saved at epoch 418 with Train RMSE: 0.0390866413619222
# Epoch  419 Train RMSE:  0.03904491416135735
# Best model saved at epoch 419 with Train RMSE: 0.03904491416135735
# Epoch  420 Train RMSE:  0.0390016812481197
# Best model saved at epoch 420 with Train RMSE: 0.0390016812481197
# Epoch  421 Train RMSE:  0.038925541749247096
# Best model saved at epoch 421 with Train RMSE: 0.038925541749247096
# Epoch  422 Train RMSE:  0.03889586400766352
# Best model saved at epoch 422 with Train RMSE: 0.03889586400766352
# Epoch  423 Train RMSE:  0.03883073417581761
# Best model saved at epoch 423 with Train RMSE: 0.03883073417581761
# Epoch  424 Train RMSE:  0.038776239900507124
# Best model saved at epoch 424 with Train RMSE: 0.038776239900507124
# Epoch  425 Train RMSE:  0.03873837225409887
# Best model saved at epoch 425 with Train RMSE: 0.03873837225409887
# Epoch  426 Train RMSE:  0.038671283885984925
# Best model saved at epoch 426 with Train RMSE: 0.038671283885984925
# Epoch  427 Train RMSE:  0.03862893925267207
# Best model saved at epoch 427 with Train RMSE: 0.03862893925267207
# Epoch  428 Train RMSE:  0.03857969746131254
# Best model saved at epoch 428 with Train RMSE: 0.03857969746131254
# Epoch  429 Train RMSE:  0.03852021535529565
# Best model saved at epoch 429 with Train RMSE: 0.03852021535529565
# Epoch  430 Train RMSE:  0.03848200955538141
# Best model saved at epoch 430 with Train RMSE: 0.03848200955538141
# Epoch  431 Train RMSE:  0.03842459402861104
# Best model saved at epoch 431 with Train RMSE: 0.03842459402861104
# Epoch  432 Train RMSE:  0.03837562545799028
# Best model saved at epoch 432 with Train RMSE: 0.03837562545799028
# Epoch  433 Train RMSE:  0.038332011240910506
# Best model saved at epoch 433 with Train RMSE: 0.038332011240910506
# Epoch  434 Train RMSE:  0.03827606939761284
# Best model saved at epoch 434 with Train RMSE: 0.03827606939761284
# Epoch  435 Train RMSE:  0.038230978973852824
# Best model saved at epoch 435 with Train RMSE: 0.038230978973852824
# Epoch  436 Train RMSE:  0.03818430180393143
# Best model saved at epoch 436 with Train RMSE: 0.03818430180393143
# Epoch  437 Train RMSE:  0.03813174744994176
# Best model saved at epoch 437 with Train RMSE: 0.03813174744994176
# Epoch  438 Train RMSE:  0.038088159618598565
# Best model saved at epoch 438 with Train RMSE: 0.038088159618598565
# Epoch  439 Train RMSE:  0.03803882833717447
# Best model saved at epoch 439 with Train RMSE: 0.03803882833717447
# Epoch  440 Train RMSE:  0.03799012707979535
# Best model saved at epoch 440 with Train RMSE: 0.03799012707979535
# Epoch  441 Train RMSE:  0.03794689197592916
# Best model saved at epoch 441 with Train RMSE: 0.03794689197592916
# Epoch  442 Train RMSE:  0.0378969805342456
# Best model saved at epoch 442 with Train RMSE: 0.0378969805342456
# Epoch  443 Train RMSE:  0.03785042203005886
# Best model saved at epoch 443 with Train RMSE: 0.03785042203005886
# Epoch  444 Train RMSE:  0.03780584473305998
# Best model saved at epoch 444 with Train RMSE: 0.03780584473305998
# Epoch  445 Train RMSE:  0.037757831141042815
# Best model saved at epoch 445 with Train RMSE: 0.037757831141042815
# Epoch  446 Train RMSE:  0.03771351790949842
# Best model saved at epoch 446 with Train RMSE: 0.03771351790949842
# Epoch  447 Train RMSE:  0.03766849118277599
# Best model saved at epoch 447 with Train RMSE: 0.03766849118277599
# Epoch  448 Train RMSE:  0.03762159576215745
# Best model saved at epoch 448 with Train RMSE: 0.03762159576215745
# Epoch  449 Train RMSE:  0.03757822630793265
# Best model saved at epoch 449 with Train RMSE: 0.03757822630793265
# Epoch  450 Train RMSE:  0.03753270849910499
# Best model saved at epoch 450 with Train RMSE: 0.03753270849910499
# Epoch  451 Train RMSE:  0.03748740249127337
# Best model saved at epoch 451 with Train RMSE: 0.03748740249127337
# Epoch  452 Train RMSE:  0.037443720599778046
# Best model saved at epoch 452 with Train RMSE: 0.037443720599778046
# Epoch  453 Train RMSE:  0.03739915814292112
# Best model saved at epoch 453 with Train RMSE: 0.03739915814292112
# Epoch  454 Train RMSE:  0.03735569716920937
# Best model saved at epoch 454 with Train RMSE: 0.03735569716920937
# Epoch  455 Train RMSE:  0.03731189696814667
# Best model saved at epoch 455 with Train RMSE: 0.03731189696814667
# Epoch  456 Train RMSE:  0.037268251455467964
# Best model saved at epoch 456 with Train RMSE: 0.037268251455467964
# Epoch  457 Train RMSE:  0.037225561771471544
# Best model saved at epoch 457 with Train RMSE: 0.037225561771471544
# Epoch  458 Train RMSE:  0.037181977725525985
# Best model saved at epoch 458 with Train RMSE: 0.037181977725525985
# Epoch  459 Train RMSE:  0.03713897885755665
# Best model saved at epoch 459 with Train RMSE: 0.03713897885755665
# Epoch  460 Train RMSE:  0.037096096473977984
# Best model saved at epoch 460 with Train RMSE: 0.037096096473977984
# Epoch  461 Train RMSE:  0.037053503779546124
# Best model saved at epoch 461 with Train RMSE: 0.037053503779546124
# Epoch  462 Train RMSE:  0.03701156663989211
# Best model saved at epoch 462 with Train RMSE: 0.03701156663989211
# Epoch  463 Train RMSE:  0.03697011724551237
# Best model saved at epoch 463 with Train RMSE: 0.03697011724551237
# Epoch  464 Train RMSE:  0.036927860005072664
# Best model saved at epoch 464 with Train RMSE: 0.036927860005072664
# Epoch  465 Train RMSE:  0.03688692566311575
# Best model saved at epoch 465 with Train RMSE: 0.03688692566311575
# Epoch  466 Train RMSE:  0.03684472309217583
# Best model saved at epoch 466 with Train RMSE: 0.03684472309217583
# Epoch  467 Train RMSE:  0.036803734240275415
# Best model saved at epoch 467 with Train RMSE: 0.036803734240275415
# Epoch  468 Train RMSE:  0.03676323168420672
# Best model saved at epoch 468 with Train RMSE: 0.03676323168420672
# Epoch  469 Train RMSE:  0.036720866347764246
# Best model saved at epoch 469 with Train RMSE: 0.036720866347764246
# Epoch  470 Train RMSE:  0.036680334177400235
# Best model saved at epoch 470 with Train RMSE: 0.036680334177400235
# Epoch  471 Train RMSE:  0.036640208342100695
# Best model saved at epoch 471 with Train RMSE: 0.036640208342100695
# Epoch  472 Train RMSE:  0.03659988583955474
# Best model saved at epoch 472 with Train RMSE: 0.03659988583955474
# Epoch  473 Train RMSE:  0.036559409006808735
# Best model saved at epoch 473 with Train RMSE: 0.036559409006808735
# Epoch  474 Train RMSE:  0.03651948342619566
# Best model saved at epoch 474 with Train RMSE: 0.03651948342619566
# Epoch  475 Train RMSE:  0.03647944872770196
# Best model saved at epoch 475 with Train RMSE: 0.03647944872770196
# Epoch  476 Train RMSE:  0.036440122404493555
# Best model saved at epoch 476 with Train RMSE: 0.036440122404493555
# Epoch  477 Train RMSE:  0.03640047535357076
# Best model saved at epoch 477 with Train RMSE: 0.03640047535357076
# Epoch  478 Train RMSE:  0.036360541744429965
# Best model saved at epoch 478 with Train RMSE: 0.036360541744429965
# Epoch  479 Train RMSE:  0.03632166039722145
# Best model saved at epoch 479 with Train RMSE: 0.03632166039722145
# Epoch  480 Train RMSE:  0.036282695672667
# Best model saved at epoch 480 with Train RMSE: 0.036282695672667
# Epoch  481 Train RMSE:  0.03624374526833446
# Best model saved at epoch 481 with Train RMSE: 0.03624374526833446
# Epoch  482 Train RMSE:  0.036204995726971986
# Best model saved at epoch 482 with Train RMSE: 0.036204995726971986
# Epoch  483 Train RMSE:  0.036165808741614416
# Best model saved at epoch 483 with Train RMSE: 0.036165808741614416
# Epoch  484 Train RMSE:  0.03612782791913214
# Best model saved at epoch 484 with Train RMSE: 0.03612782791913214
# Epoch  485 Train RMSE:  0.036089050688371906
# Best model saved at epoch 485 with Train RMSE: 0.036089050688371906
# Epoch  486 Train RMSE:  0.036050968009307086
# Best model saved at epoch 486 with Train RMSE: 0.036050968009307086
# Epoch  487 Train RMSE:  0.036013237818217525
# Best model saved at epoch 487 with Train RMSE: 0.036013237818217525
# Epoch  488 Train RMSE:  0.03597559102307232
# Best model saved at epoch 488 with Train RMSE: 0.03597559102307232
# Epoch  489 Train RMSE:  0.03593794366313903
# Best model saved at epoch 489 with Train RMSE: 0.03593794366313903
# Epoch  490 Train RMSE:  0.03589971366010787
# Best model saved at epoch 490 with Train RMSE: 0.03589971366010787
# Epoch  491 Train RMSE:  0.03586247032650195
# Best model saved at epoch 491 with Train RMSE: 0.03586247032650195
# Epoch  492 Train RMSE:  0.03582537999754791
# Best model saved at epoch 492 with Train RMSE: 0.03582537999754791
# Epoch  493 Train RMSE:  0.035788033284396246
# Best model saved at epoch 493 with Train RMSE: 0.035788033284396246
# Epoch  494 Train RMSE:  0.035750133055972036
# Best model saved at epoch 494 with Train RMSE: 0.035750133055972036
# Epoch  495 Train RMSE:  0.03571399035076212
# Best model saved at epoch 495 with Train RMSE: 0.03571399035076212
# Epoch  496 Train RMSE:  0.035677757193009425
# Best model saved at epoch 496 with Train RMSE: 0.035677757193009425
# Epoch  497 Train RMSE:  0.03564035541425359
# Best model saved at epoch 497 with Train RMSE: 0.03564035541425359
# Epoch  498 Train RMSE:  0.035603754679256985
# Best model saved at epoch 498 with Train RMSE: 0.035603754679256985
# Epoch  499 Train RMSE:  0.03556696571620222
# Best model saved at epoch 499 with Train RMSE: 0.03556696571620222
# Training time: 429.44553208351135

# %% [markdown]
# # 模型可视化

# %%
# 加载最优模型参数
model.load_state_dict(torch.load(best_model_path,weights_only=True))  
model.eval()  # 将模型设置为评估模式

# 加载归一化格式
scaler = joblib.load(best_scaler_path)

 # 得到最好预测
with torch.no_grad():  # 禁用梯度计算
    y_train_pred = model(x_train)
    
# 训练预测值反归一化
y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
# 训练原始值反归一化
y_train = scaler.inverse_transform(y_train_lstm.detach().numpy())


# 计算MSE
trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.3f RMSE' % (trainScore))
# Out:
# Train Score: 0.036 RMSE

# %%
y_train = pd.DataFrame(y_train)
y_train_pred = pd.DataFrame(y_train_pred)

# 模型结果可视化
sns.set_style("darkgrid")
fig = plt.figure()
fig.subplots_adjust(hspace=0.2,wspace=0.2)
plt.subplot(1,2,1)
ax = sns.lineplot(x=y_train.index,y=y_train[0],label="origin",color='royalblue')
ax = sns.lineplot(x=y_train_pred.index,y=y_train_pred[0],label="predict",color='tomato')
ax.set_title(f'水地8-12水位监测点LSTM训练集预测结果对比',size=14,fontweight='bold',fontfamily=["SimHei"])
ax.set_xlabel("Time",size=14)
ax.set_ylabel("Data",size=14)
ax.set_xticklabels('',size=10)

plt.subplot(1,2,2)
ax = sns.lineplot(data=hist,color='royalblue')
ax.set_xlabel("Epoch",size=14)
ax.set_ylabel("Loss",size=14)
ax.set_title("Training Loss",size=14,fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)
plt.savefig('./images/水地8-12.png', dpi=300, bbox_inches='tight')

plt.show()
